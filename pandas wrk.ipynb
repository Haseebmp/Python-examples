# %%
import pandas as pd

# %%
cars=pd.read_csv(r"C:\Users\admin\Documents\haseeb pandas\Automobile_data.csv")

# %%
cars
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
cars.head(61)
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
cars.tail(5)
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 56     81  volkswagen      sedan        97.3   171.7         ohc
# 57     82  volkswagen      sedan        97.3   171.7         ohc
# 58     86  volkswagen      sedan        97.3   171.7         ohc
# 59     87       volvo      sedan       104.3   188.8         ohc
# 60     88       volvo      wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 56             four          85               27   7975.0
# 57             four          52               37   7995.0
# 58             four         100               26   9995.0
# 59             four         114               23  12940.0
# 60             four         114               23  13415.0

# %%
cars.describe()
# Out:
#            index  wheel-base      length  horsepower  average-mileage  \
# count  61.000000   61.000000   61.000000   61.000000        61.000000
# mean   40.885246   98.481967  173.098361  107.852459        25.803279
# std    25.429706    6.679234   14.021846   53.524398         8.129821
# min     0.000000   88.400000  141.100000   48.000000        13.000000
# 25%    18.000000   94.500000  159.100000   68.000000        19.000000
# 50%    39.000000   96.300000  171.200000  100.000000        25.000000
# 75%    61.000000  101.200000  177.300000  123.000000        31.000000
# max    88.000000  120.900000  208.100000  288.000000        47.000000
#
#               price
# count     58.000000
# mean   15387.000000
# std    11320.259841
# min     5151.000000
# 25%     6808.500000
# 50%    11095.000000
# 75%    18120.500000
# max    45400.000000

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             61 non-null     int64
#  1   company           61 non-null     object
#  2   body-style        61 non-null     object
#  3   wheel-base        61 non-null     float64
#  4   length            61 non-null     float64
#  5   engine-type       61 non-null     object
#  6   num-of-cylinders  61 non-null     object
#  7   horsepower        61 non-null     int64
#  8   average-mileage   61 non-null     int64
#  9   price             58 non-null     float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 4.9+ KB

# %%
cars.describe(include="object")
# Out:
#        company body-style engine-type num-of-cylinders
# count       61         61          61               61
# unique      16          5           7                7
# top     toyota      sedan         ohc             four
# freq         7         32          46               39

# %%
cars.loc[1:61]
# Out:
#     index        company   body-style  wheel-base  length engine-type  \
# 1       1    alfa-romero  convertible        88.6   168.8        dohc
# 2       2    alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3           audi        sedan        99.8   176.6         ohc
# 4       4           audi        sedan        99.4   176.6         ohc
# 5       5           audi        sedan        99.8   177.3         ohc
# 6       6           audi        wagon       105.8   192.7         ohc
# 7       9            bmw        sedan       101.2   176.8         ohc
# 8      10            bmw        sedan       101.2   176.8         ohc
# 9      11            bmw        sedan       101.2   176.8         ohc
# 10     13            bmw        sedan       103.5   189.0         ohc
# 11     14            bmw        sedan       103.5   193.8         ohc
# 12     15            bmw        sedan       110.0   197.0         ohc
# ...

# %%
cars["company"].value_counts()
# Out:
# company
# toyota           7
# bmw              6
# mazda            5
# nissan           5
# audi             4
# mercedes-benz    4
# mitsubishi       4
# volkswagen       4
# alfa-romero      3
# chevrolet        3
# honda            3
# isuzu            3
# jaguar           3
# porsche          3
# dodge            2
# volvo            2
# Name: count, dtype: int64

# %%
cars.sort_values(by="price")
# Out:
#     index        company body-style  wheel-base  length engine-type  \
# 13     16      chevrolet  hatchback        88.4   141.1           l
# 27     36          mazda  hatchback        93.1   159.1         ohc
# 48     66         toyota  hatchback        95.7   158.7         ohc
# 36     49     mitsubishi  hatchback        93.7   157.3         ohc
# 28     37          mazda  hatchback        93.1   159.1         ohc
# ..    ...            ...        ...         ...     ...         ...
# 11     14            bmw      sedan       103.5   193.8         ohc
# 35     47  mercedes-benz    hardtop       112.0   199.2        ohcv
# 22     31          isuzu      sedan        94.5   155.9         ohc
# 23     32          isuzu      sedan        94.5   155.9         ohc
# 47     63        porsche  hatchback        98.4   175.7       dohcv
#
#    num-of-cylinders  horsepower  average-mileage    price
# 13            three          48               47   5151.0
# ...

# %%
cars=cars.dropna()

# %%
cars.isna().sum()
# Out:
# index               0
# company             0
# body-style          0
# wheel-base          0
# length              0
# engine-type         0
# num-of-cylinders    0
# horsepower          0
# average-mileage     0
# price               0
# dtype: int64

# %%
cars
# Out:
#     index        company   body-style  wheel-base  length engine-type  \
# 0       0    alfa-romero  convertible        88.6   168.8        dohc
# 1       1    alfa-romero  convertible        88.6   168.8        dohc
# 2       2    alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3           audi        sedan        99.8   176.6         ohc
# 4       4           audi        sedan        99.4   176.6         ohc
# 5       5           audi        sedan        99.8   177.3         ohc
# 6       6           audi        wagon       105.8   192.7         ohc
# 7       9            bmw        sedan       101.2   176.8         ohc
# 8      10            bmw        sedan       101.2   176.8         ohc
# 9      11            bmw        sedan       101.2   176.8         ohc
# 10     13            bmw        sedan       103.5   189.0         ohc
# 11     14            bmw        sedan       103.5   193.8         ohc
# ...

# %%
cars.sort_values(by="price").tail(1)
# Out:
#     index        company body-style  wheel-base  length engine-type  \
# 35     47  mercedes-benz    hardtop       112.0   199.2        ohcv
#
#    num-of-cylinders  horsepower  average-mileage    price
# 35            eight         184               14  45400.0

# %%
cars
# Out:
#     index        company   body-style  wheel-base  length engine-type  \
# 0       0    alfa-romero  convertible        88.6   168.8        dohc
# 1       1    alfa-romero  convertible        88.6   168.8        dohc
# 2       2    alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3           audi        sedan        99.8   176.6         ohc
# 4       4           audi        sedan        99.4   176.6         ohc
# 5       5           audi        sedan        99.8   177.3         ohc
# 6       6           audi        wagon       105.8   192.7         ohc
# 7       9            bmw        sedan       101.2   176.8         ohc
# 8      10            bmw        sedan       101.2   176.8         ohc
# 9      11            bmw        sedan       101.2   176.8         ohc
# 10     13            bmw        sedan       103.5   189.0         ohc
# 11     14            bmw        sedan       103.5   193.8         ohc
# ...

# %%
cars[cars["company"]=="volvo"]
# Out:
#     index company body-style  wheel-base  length engine-type num-of-cylinders  \
# 59     87   volvo      sedan       104.3   188.8         ohc             four
# 60     88   volvo      wagon       104.3   188.8         ohc             four
#
#     horsepower  average-mileage    price
# 59         114               23  12940.0
# 60         114               23  13415.0

# %%
student_dict={'name':['joe','nat','harry'],'class':['A','B','A'],'marks':[85.10,77.80,91.54]}

# %%
student_dict
# Out:
# {'name': ['joe', 'nat', 'harry'],
#  'class': ['A', 'B', 'A'],
#  'marks': [85.1, 77.8, 91.54]}

# %%
student_df=pd.DataFrame(student_dict)

# %%
student_df
# Out:
#     name class  marks
# 0    joe     A  85.10
# 1    nat     B  77.80
# 2  harry     A  91.54

# %%
student_df.groupby(["class"]).mean("class")
# Out:
#        marks
# class
# A      88.32
# B      77.80

# %%
student_df["marks"]/3
# Out:
# 0    28.366667
# 1    25.933333
# 2    30.513333
# Name: marks, dtype: float64

# %%
cars.describe(include="object")
# Out:
#        company body-style engine-type num-of-cylinders
# count       58         58          58               58
# unique      16          5           6                7
# top     toyota      sedan         ohc             four
# freq         7         30          44               37

# %%
cars.groupby("company").count()
# Out:
#                index  body-style  wheel-base  length  engine-type  \
# company
# alfa-romero        3           3           3       3            3
# audi               4           4           4       4            4
# bmw                6           6           6       6            6
# chevrolet          3           3           3       3            3
# dodge              2           2           2       2            2
# honda              3           3           3       3            3
# isuzu              1           1           1       1            1
# jaguar             3           3           3       3            3
# mazda              5           5           5       5            5
# mercedes-benz      4           4           4       4            4
# mitsubishi         4           4           4       4            4
# nissan             5           5           5       5            5
# porsche            2           2           2       2            2
# ...

# %%
cars.groupby("company").sum()
# Out:
#                index                                       body-style  \
# company
# alfa-romero        3                  convertibleconvertiblehatchback
# audi              18                             sedansedansedanwagon
# bmw               72                   sedansedansedansedansedansedan
# chevrolet         51                          hatchbackhatchbacksedan
# dodge             39                               hatchbackhatchback
# honda             84                                  wagonsedansedan
# isuzu             30                                            sedan
# jaguar           102                                  sedansedansedan
# mazda            193        hatchbackhatchbackhatchbackhatchbacksedan
# mercedes-benz    182                           sedanwagonsedanhardtop
# mitsubishi       202                     hatchbackhatchbacksedansedan
# nissan           275                        sedansedansedanwagonsedan
# ...

# %%
cars.groupby(["company","engine-type"]).sum()
# Out:
#                            index                                  body-style  \
# company       engine-type
# alfa-romero   dohc             1                      convertibleconvertible
#               ohcv             2                                   hatchback
# audi          ohc             18                        sedansedansedanwagon
# bmw           ohc             72              sedansedansedansedansedansedan
# chevrolet     l               16                                   hatchback
#               ohc             35                              hatchbacksedan
# dodge         ohc             39                          hatchbackhatchback
# honda         ohc             84                             wagonsedansedan
# isuzu         ohc             30                                       sedan
# jaguar        dohc            67                                  sedansedan
#               ohcv            35                                       sedan
# ...
